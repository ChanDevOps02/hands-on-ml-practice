# %% [markdown]
# ## 2. 데이터 이해를 위한 탐색 및 시각화
#
# 본 챕터에서는 데이터의 전반적인 특성을 파악하기 위해
# `matplotlib`을 활용한 시각화를 수행한다.
# 주요 변수들의 분포를 확인하고, 데이터가 가지는 구조적 특징을
# 직관적으로 이해함으로써 이후 전처리 및 모델링 방향을 설정한다.

# %% [markdown]
# ### (1) 지리적 데이터 시각화
#
# 위도(latitude)와 경도(longitude)를 기준으로 산점도(scatter plot)를 생성하여
# 주택 데이터의 지리적 분포를 시각화한다.
# 이를 통해 주택이 특정 지역에 밀집되어 있는 패턴을 직관적으로 확인할 수 있으며,
# 공간적 특성이 모델링에 중요한 요인이 될 수 있음을 파악한다.

# %%
housing = strat_train_set.copy()

# %%
housing.plot(kind = "scatter", x = "longitude", y = "latitude", alpha = 0.4, s = housing['population']/100, label = "population", figsize = (10, 7),
             c = "median_house_value", cmap = plt.get_cmap("jet"), colorbar = True, sharex=False)
plt.legend()
